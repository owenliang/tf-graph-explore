# %% [markdown]
# 参考：https://www.tensorflow.org/guide/keras/functional

# %%
import tensorflow as tf

# %%
inputs=tf.keras.Input(shape=(2,),dtype=tf.float32,name='input')

# %%
dense1=tf.keras.layers.Dense(1,activation=None,name='dense1')
dense2=tf.keras.layers.Dense(2,activation=None,name='dense2')
dense3=tf.keras.layers.Dense(1,activation=None,name='dense3')

# %%
outputs1=dense1(inputs)
outputs2=dense2(inputs)
outputs3=tf.keras.layers.concatenate([outputs1,outputs2],axis=1,name='concat')
outputs4=dense3(outputs3)

# %%
model=tf.keras.Model(inputs=inputs,outputs=outputs4)

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 2)]          0
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 1)            3           input[0][0]
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 2)            6           input[0][0]
# __________________________________________________________________________________________________
# concat (Concatenate)            (None, 3)            0           dense1[0][0]
#                                                                  dense2[0][0]
# __________________________________________________________________________________________________
# dense3 (Dense)                  (None, 1)            4           concat[0][0]
# ==================================================================================================
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, "graph.png", show_shapes=True)

# %%
data=tf.random.normal(shape=(10,2))
print(data)
# Out:
# tf.Tensor(
# [[-1.4014436   0.38094786]
#  [-0.6867268  -0.13519928]
#  [ 0.4199749  -1.1125628 ]
#  [-1.7357036   1.1385295 ]
#  [ 2.1131568  -0.06280915]
#  [ 1.7109112  -0.5793534 ]
#  [-2.2679398   0.76951164]
#  [ 0.05281466  0.15128912]
#  [-0.00837216 -1.1092117 ]
#  [-0.22623906  0.05789325]], shape=(10, 2), dtype=float32)

# %%
model(data)
# Out:
# <tf.Tensor: shape=(10, 1), dtype=float32, numpy=
# array([[ 1.5846565 ],
#        [ 0.58478147],
#        [-1.0695801 ],
#        [ 2.3597488 ],
#        [-2.0846767 ],
#        [-2.0026548 ],
#        [ 2.6555824 ],
#        [ 0.03894797],
#        [-0.65259373],
#        [ 0.25366873]], dtype=float32)>
